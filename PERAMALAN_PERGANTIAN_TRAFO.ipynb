# %% [markdown]
# <a href="https://colab.research.google.com/github/Khamdanfakhryza/Artificial-Neural-Network/blob/main/PERAMALAN_PERGANTIAN_TRAFO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow

# %%
import pandas as pd
import numpy as np

# Set seed for reproducibility
np.random.seed(0)

# Jumlah data yang dihasilkan
num_records = 1000

# Nama trafo
transformer_names = [
    'Trafo Tembalang', 'Trafo Jatingaleh', 'Trafo Kota Lama', 'Trafo Mijen', 'Trafo Tegalsari',
    'Trafo Banyumanik', 'Trafo Pedurungan', 'Trafo Tanah Mas', 'Trafo Jatingaleh', 'Trafo Kaligawe',
    'Trafo Srondol', 'Trafo Jatingaleh', 'Trafo Mijen', 'Trafo Jatingaleh', 'Trafo Mangunharjo',
    'Trafo Plamongan', 'Trafo Johar', 'Trafo Tanah Mas', 'Trafo Semarang Barat', 'Trafo Jatingaleh',
    'Trafo Karangayu', 'Trafo Bangetayu', 'Trafo Tanah Mas', 'Trafo Plamongan'
]

# Fungsi untuk data
def generate_data(num_records):
    data = []
    for _ in range(num_records):
        name = np.random.choice(transformer_names)
        actual_age = np.random.choice([16, 5, 15, 20, 20, 21, 22, 2, 1, 5, 21, 10, 4, 12, 19, 5, 1, 3, 3, 12, 15, 5, 16, 23])
        predicted_age = np.random.choice([10, 20, 11, 6, 4, 5, 3, 24, 24, 19, 4, 14, 21, 13, 6, 20, 19, 24, 15, 10, 19, 10, 10, 2])
        remaining_life = predicted_age - actual_age
        end_of_life_year = 2024 + np.random.randint(15, 40)  # Tahun akhir hidup antara 2024 dan 2063
        load = np.random.uniform(50, 100)  # Beban antara 50 dan 100
        operating_temp = np.random.uniform(50, 80)  # Suhu operasi antara 50 dan 80
        oil_quality = np.random.uniform(0.5, 1.0)  # Kualitas minyak antara 0.5 dan 1.0
        peak_load = np.random.uniform(100, 220)  # Beban puncak antara 100 dan 220
        lowest_load = np.random.uniform(50, 130)  # Beban terendah antara 50 dan 130
        population = np.random.randint(1600000, 1700000)  # Populasi antara 1.6 juta dan 1.7 juta
        energy_production = np.random.uniform(1e6, 1.5e6)  # Energi produksi antara 1 juta dan 1.5 juta MWh

        data.append([
            name, actual_age, round(predicted_age, 3),
            round(remaining_life, 2), end_of_life_year,
            round(load, 8), round(operating_temp, 8), round(oil_quality, 9),
            round(peak_load, 8), round(lowest_load, 8), population, round(energy_production, 8)
        ])

    df = pd.DataFrame(data, columns=[
        'Transformer Name', 'Actual Age', 'Predicted Age',
        'Remaining Life', 'End of Life Year', 'Load',
        'Operating Temperature', 'Oil Quality', 'Peak Load',
        'Lowest Load', 'Population', 'Energy Production MWh'
    ])
    return df

# Generate data
df = generate_data(num_records)

# Simpan data ke file CSV
df.to_csv('/content/transformer_data.csv', index=False)

print("Data berhasil dibuat dan disimpan ke '/content/transformer_data.csv'.")
# Out:
# Data berhasil dibuat dan disimpan ke '/content/transformer_data.csv'.

# %%
import pandas as pd
import numpy as np

# Set seed for reproducibility
np.random.seed(0)

# Jumlah data yang dihasilkan
num_records = 1000

# Nama trafo
transformer_names = [
    'Trafo Bangetayu', 'Trafo Plamongan', 'Trafo Banjirkanal Timur',
    'Trafo Mangunharjo', 'Trafo Pedurungan', 'Trafo Jatingaleh',
    'Trafo Kaligawe', 'Trafo Semarang Timur', 'Trafo Semarang Barat',
    'Trafo Genuk', 'Trafo Banyumanik', 'Trafo Karangayu',
    'Trafo Tembalang', 'Trafo Jatingaleh', 'Trafo Tugu',
    'Trafo Srondol', 'Trafo Mijen', 'Trafo Semarang Barat',
    'Trafo Jatingaleh', 'Trafo Tegalsari', 'Trafo Mijen',
    'Trafo Karangayu', 'Trafo Johar', 'Trafo Kota Lama',
    'Trafo Tanah Mas'
]

# Fungsi untuk menghasilkan data
def generate_data(num_records):
    data = []
    for _ in range(num_records):
        name = np.random.choice(transformer_names)
        actual_age = np.random.randint(1, 10)  # Usia aktual antara 1 dan 24 tahun
        predicted_age = actual_age + np.random.uniform(1, 25)  # Usia prediksi lebih besar dari usia aktual
        remaining_life = predicted_age - actual_age
        end_of_life_year = 2024 + np.random.randint(15, 25)  # Tahun akhir hidup antara 2024 dan 2063
        load = np.random.uniform(50, 100)  # Beban antara 50 dan 100
        operating_temp = np.random.uniform(50, 80)  # Suhu operasi antara 50 dan 80
        oil_quality = np.random.uniform(0.5, 1.0)  # Kualitas minyak antara 0.5 dan 1.0
        peak_load = np.random.uniform(100, 220)  # Beban puncak antara 100 dan 220
        lowest_load = np.random.uniform(50, 130)  # Beban terendah antara 50 dan 130
        population = np.random.randint(1600000, 1700000)  # Populasi antara 1.6 juta dan 1.7 juta
        energy_production = np.random.uniform(1e6, 1.5e6)  # Energi produksi antara 1 juta dan 1.5 juta MWh

        data.append([
            name, actual_age, round(predicted_age, 3),
            round(remaining_life, 2), end_of_life_year,
            round(load, 8), round(operating_temp, 8), round(oil_quality, 9),
            round(peak_load, 8), round(lowest_load, 8), population, round(energy_production, 8)
        ])

    df = pd.DataFrame(data, columns=[
        'Transformer Name', 'Actual Age', 'Predicted Age',
        'Remaining Life', 'End of Life Year', 'Load',
        'Operating Temperature', 'Oil Quality', 'Peak Load',
        'Lowest Load', 'Population', 'Energy Production MWh'
    ])
    return df

# Generate data
df = generate_data(num_records)

# Simpan data ke file CSV
df.to_csv('/content/transformer_data.csv', index=False)

print("Data berhasil dibuat dan disimpan ke '/content/transformer_data.csv'.")
# Out:
# Data berhasil dibuat dan disimpan ke '/content/transformer_data.csv'.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# Muat data
df = pd.read_csv('/content/transformer_data.csv')

# Tampilkan beberapa baris data
df.head()
# Out:
#    Transformer Name  Actual Age  Predicted Age  Remaining Life  \
# 0   Trafo Tembalang           6         27.262           21.26
# 1    Trafo Kaligawe           8         21.693           13.69
# 2     Trafo Srondol           1         25.487           24.49
# 3  Trafo Banyumanik           5         17.366           12.37
# 4  Trafo Pedurungan           9         31.656           22.66
#
#    End of Life Year       Load  Operating Temperature  Oil Quality  \
# 0              2042  92.362587              68.706911     0.692191
# 1              2047  69.639240              75.082363     0.668698
# 2              2047  90.045538              65.614324     0.839440
# 3              2041  72.807517              67.053018     0.509395
# 4              2046  53.011274              70.003001     0.835319
#
#     Peak Load  Lowest Load  Population  Energy Production MWh
# 0  135.704153    54.537038     1652620           1.191721e+06
# ...

# %%
# @title Remaining Life

from matplotlib import pyplot as plt
df['Remaining Life'].plot(kind='hist', bins=20, title='Remaining Life')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1h9ugN_DLvBMawSOdrawAGkkk4n9MZHBJWXr7UFnYzcI#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1h9ugN_DLvBMawSOdrawAGkkk4n9MZHBJWXr7UFnYzcI#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#DOWNLOAD FILE LAPORAN
from google.colab import files
files.download('/content/transformer_data.csv')

# %%
# Fitur dan target
X = df[['Actual Age', 'Remaining Life', 'End of Life Year']]
y = df['Predicted Age']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Standarisasi data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Buat model ANN
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))  # Output layer untuk regresi

# Kompilasi model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Latih model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# 20/20 [==============================] - 1s 15ms/step - loss: 349.4626 - val_loss: 370.4054
# Epoch 2/50
# 20/20 [==============================] - 0s 4ms/step - loss: 315.7548 - val_loss: 329.0544
# Epoch 3/50
# 20/20 [==============================] - 0s 5ms/step - loss: 272.3717 - val_loss: 269.7126
# Epoch 4/50
# 20/20 [==============================] - 0s 5ms/step - loss: 212.9477 - val_loss: 193.8571
# Epoch 5/50
# 20/20 [==============================] - 0s 5ms/step - loss: 143.4578 - val_loss: 113.5549
# Epoch 6/50
# 20/20 [==============================] - 0s 4ms/step - loss: 77.4665 - val_loss: 50.9635
# Epoch 7/50
# 20/20 [==============================] - 0s 6ms/step - loss: 33.6214 - val_loss: 20.6267
# Epoch 8/50
# 20/20 [==============================] - 0s 5ms/step - loss: 16.1393 - val_loss: 12.6687
# Epoch 9/50
# 20/20 [==============================] - 0s 5ms/step - loss: 11.6192 - val_loss: 10.5671
# Epoch 10/50
# ...

# %%
# Prediksi
y_pred = model.predict(X_test)

# Hitung MSE dan MAPE
mse = mean_squared_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Percentage Error: {mape}")
# Out:
# 7/7 [==============================] - 0s 2ms/step
# Mean Squared Error: 0.26046316091327953
# Mean Absolute Percentage Error: 0.03067988758464936

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

# Prediksi
y_pred = model.predict(X_test)

# Visualisasi prediksi vs aktual
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.title('Predicted Age vs Actual Age')
plt.xlabel('Actual Age')
plt.ylabel('Predicted Age')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')
plt.grid(True)
plt.show()
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot histogram untuk usia aktual dan usia prediksi
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.histplot(df['Actual Age'], bins=15, kde=True)
plt.title('Distribusi Usia Aktual')
plt.xlabel('Usia Aktual')

plt.subplot(1, 2, 2)
sns.histplot(df['Predicted Age'], bins=15, kde=True)
plt.title('Distribusi Usia Prediksi')
plt.xlabel('Usia Prediksi')

plt.tight_layout()
plt.show()

# %%
# Plot jumlah trafo berdasarkan tahun akhir hidup
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='End of Life Year', palette='viridis')
plt.title('Jumlah Trafo Berdasarkan Tahun Akhir Hidup')
plt.xlabel('Tahun Akhir Hidup')
plt.ylabel('Jumlah Trafo')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-16-5e5659682119>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='End of Life Year', palette='viridis')

# %%
# Plot prediksi vs usia aktual
plt.figure(figsize=(10, 6))
plt.scatter(df['Actual Age'], df['Predicted Age'], alpha=0.5)
plt.title('Prediksi Usia vs Usia Aktual')
plt.xlabel('Usia Aktual')
plt.ylabel('Usia Prediksi')
plt.plot([df['Actual Age'].min(), df['Actual Age'].max()], [df['Actual Age'].min(), df['Actual Age'].max()], color='red', linestyle='--')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Data transformers
data = {
    'Transformer Name': ['Trafo Tembalang', 'Trafo Jatingaleh', 'Trafo Kota Lama', 'Trafo Mijen', 'Trafo Tegalsari',
                         'Trafo Banyumanik', 'Trafo Pedurungan', 'Trafo Tanah Mas', 'Trafo Jatingaleh', 'Trafo Kaligawe',
                         'Trafo Srondol', 'Trafo Jatingaleh', 'Trafo Mijen', 'Trafo Jatingaleh', 'Trafo Mangunharjo',
                         'Trafo Plamongan', 'Trafo Johar', 'Trafo Tanah Mas', 'Trafo Semarang Barat', 'Trafo Jatingaleh',
                         'Trafo Karangayu', 'Trafo Bangetayu', 'Trafo Tanah Mas', 'Trafo Plamongan'],
    'Actual Age': [16, 5, 15, 20, 20, 21, 22, 2, 1, 5, 21, 10, 4, 12, 19, 5, 1, 3, 3, 12, 15, 5, 16, 23],
    'Predicted Age': [10, 20, 11, 6, 4, 5, 3, 24, 24, 19, 4, 14, 21, 13, 6, 20, 19, 24, 15, 10, 19, 10, 10, 2]
}

# Membuat DataFrame
result_df = pd.DataFrame(data)

# Lebar bar
bar_width = 0.35

# Posisi bar di sumbu x
index = np.arange(len(result_df))

# Membuat grafik bar untuk usia aktual dan usia prediksi
plt.figure(figsize=(14, 8))
actual_age_bars = plt.bar(index, result_df['Actual Age'], bar_width, label='Actual Age', color='skyblue')
predicted_age_bars = plt.bar(index + bar_width, result_df['Predicted Age'], bar_width, label='Predicted Age', color='lightgreen')

# Menambahkan nilai pada setiap batang untuk usia aktual
for bar in actual_age_bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2.0, yval, int(yval), ha='center', va='bottom')

# Menambahkan nilai pada setiap batang untuk usia prediksi
for bar in predicted_age_bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2.0, yval, int(yval), ha='center', va='bottom')

# Tambahkan gridlines untuk referensi visual
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Setel label dan judul
plt.xlabel('Transformer Name')
plt.ylabel('Age (Years)')
plt.title('Comparison of Actual and Predicted Transformer Age')
plt.xticks(index + bar_width / 2, result_df['Transformer Name'], rotation=90)
plt.legend()

# Agar semua elemen grafik tidak terpotong
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot histogram untuk data tambahan
plt.figure(figsize=(15, 10))

plt.subplot(3, 1, 1)
sns.histplot(df['Load'], bins=15, kde=True)
plt.title('Distribusi Load')
plt.xlabel('Load')

plt.subplot(3, 1, 2)
sns.histplot(df['Operating Temperature'], bins=15, kde=True)
plt.title('Distribusi Suhu Operasi')
plt.xlabel('Suhu Operasi')

plt.subplot(3, 1, 3)
sns.histplot(df['Oil Quality'], bins=15, kde=True)
plt.title('Distribusi Kualitas Minyak')
plt.xlabel('Kualitas Minyak')

plt.tight_layout()
plt.show()
